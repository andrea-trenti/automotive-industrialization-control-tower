# %% [markdown]
# # Notebook 1
# Thin exploration layer; production logic is in `src/`.

# %%
from pathlib import Path
ROOT=Path.cwd().parent if Path.cwd().name=="notebooks" else Path.cwd()
print(ROOT)
